# %% [markdown]
# # NAME: ABISHEK JS
# # REG-NO: RA2411026010307
# # CLASS: AF-1

# %% [markdown]
# #  CODING PRACTICE SESSION - 1
#
#
# - AIM :-
#     - TO IMPORT THE FOLLOWING DATA AND CREATE DATA FRAME FORM THE IMPORTED DATA
#
# #
# - FILES USED FOR THE CODING PREACTICE:-
#
#     - DATASET IMPORTED: HOUSE PRICE PREDICTION DATASET.CSV [CSV FILE]
#             -> SOURCE: KAGGLE.COM
#
#     - EXCEL FILE USED: HOUSE PRICE PREDICTION DATASET.XLSX
#             -> SOURCE: KAGGLE.COM
#
#     - XML FILE: https://www.w3schools.com/xml/cd_catalog.xml
#         -> SOURCE: W3SCHOOLS.COM
#
#     - HTML PAGE : CREATED MY OWN DATASET HTML PAGE (SAMPLE.HTML)
#
#     - JSON FILE: https://jsonplaceholder.typicode.com/users
#         -> SOURCE: OPEN SOURCE

# %% [markdown]
# # DATAS TO BE IMPOTED
#
#   1. CSV FILE
#   2. XML FILE
#   3. EXCEL FILE
#   4. HTML FILE
#   5. JSON FILE

# %% [markdown]
# # 1.1 Importing from the csv file (House Price Prediction Dataset.csv) and getting the basic info of the data set

# %%
# importing pandas library to import data

import pandas as pd

df = pd.read_csv("House Price Prediction Dataset.csv")

print(df)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df.info()
df.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   str
#  7   Condition  2000 non-null   str
#  8   Garage     2000 non-null   str
#  9   Price      2000 non-null   int64
# dtypes: int64(7), str(3)
# memory usage: 156.4 KB
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='str')

# %% [markdown]
# # 1.2 exporting the selected datas to the EXCEL FILE as (houseprice.xlsx)

# %%
selected  = df[["Bedrooms","Price"]]

selected.to_excel("bedroomtoaera price.xlsx", index=False)

df.to_excel("houseprice.xlsx", index=False)

# %% [markdown]
# # 2.1 Importing the excel file (houseprice.xlsx) via pandas and getting the basic info of the data set

# %%
df1 = pd.read_excel("houseprice.xlsx" , sheet_name="Sheet1")

print(df1)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0        1  1360         5          4       3       1970  Downtown  Excellent
# 1        2  4272         5          4       3       1958  Downtown  Excellent
# 2        3  3592         2          2       3       1938  Downtown       Good
# 3        4   966         4          2       2       1902  Suburban       Fair
# 4        5  4926         1          4       2       1975  Downtown       Fair
# ...    ...   ...       ...        ...     ...        ...       ...        ...
# 1995  1996  4994         5          4       3       1923  Suburban       Poor
# 1996  1997  3046         5          2       1       2019  Suburban       Poor
# 1997  1998  1062         5          1       2       1903     Rural       Poor
# 1998  1999  4062         3          1       2       1936     Urban  Excellent
# 1999  2000  2989         5          1       3       1903  Suburban       Fair
#
#      Garage   Price
# ...

# %%
df1.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
df1.info()
df1.columns
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   str
#  7   Condition  2000 non-null   str
#  8   Garage     2000 non-null   str
#  9   Price      2000 non-null   int64
# dtypes: int64(7), str(3)
# memory usage: 156.4 KB
# Index(['Id', 'Area', 'Bedrooms', 'Bathrooms', 'Floors', 'YearBuilt',
#        'Location', 'Condition', 'Garage', 'Price'],
#       dtype='str')

# %% [markdown]
# # 3.1 Importing a Xml file and getting the basic info of the xml file

# %%
df2 = pd.read_xml("https://www.w3schools.com/xml/cd_catalog.xml")

print(df2)
# Out:
#                        TITLE             ARTIST COUNTRY         COMPANY  \
# 0           Empire Burlesque          Bob Dylan     USA        Columbia
# 1            Hide your heart       Bonnie Tyler      UK     CBS Records
# 2              Greatest Hits       Dolly Parton     USA             RCA
# 3        Still got the blues         Gary Moore      UK  Virgin records
# 4                       Eros    Eros Ramazzotti      EU             BMG
# 5             One night only           Bee Gees      UK         Polydor
# 6             Sylvias Mother            Dr.Hook      UK             CBS
# 7                 Maggie May        Rod Stewart      UK        Pickwick
# 8                    Romanza     Andrea Bocelli      EU         Polydor
# 9   When a man loves a woman       Percy Sledge     USA        Atlantic
# 10               Black angel        Savage Rose      EU            Mega
# 11      1999 Grammy Nominees               Many     USA          Grammy
# ...

# %%
df2.head()
# Out:
#                  TITLE           ARTIST COUNTRY         COMPANY  PRICE  YEAR
# 0     Empire Burlesque        Bob Dylan     USA        Columbia   10.9  1985
# 1      Hide your heart     Bonnie Tyler      UK     CBS Records    9.9  1988
# 2        Greatest Hits     Dolly Parton     USA             RCA    9.9  1982
# 3  Still got the blues       Gary Moore      UK  Virgin records   10.2  1990
# 4                 Eros  Eros Ramazzotti      EU             BMG    9.9  1997

# %% [markdown]
# # 3.2 Exporting the xml file to excel file named as (cdcatlog.xlsx)

# %%
df2.to_excel("cd_catalog.xlsx", index=False)

# %% [markdown]
# # 4.1 Importing the HTML File and getting the basic info

# %%
df3 = pd.read_html("sample.html")

print(df3)
# Out:
# [  House ID  Area  Bedrooms  Bathrooms  Floors  Parking    Location     Price
# 0     H101  1200         2          2       1        1     Chennai   4500000
# 1     H102  1500         3          2       2        1   Bangalore   6200000
# 2     H103  1800         3          3       2        2   Hyderabad   7900000
# 3     H104  2200         4          3       2        2      Mumbai  12000000
# 4     H105  2800         5          4       3        3       Delhi  18000000
# 5     H106  1600         3          2       2        1  Coimbatore   5800000
# 6     H107  1350         2          2       1        1     Madurai   4100000
# 7     H108  3000         5          5       3        3     Chennai  21000000]

# %%
df.head()
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056

# %%
# df.info()
df.columns
df.describe()
# Out:
#                 Id         Area     Bedrooms   Bathrooms       Floors  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean   1000.500000  2786.209500     3.003500     2.55250     1.993500
# std     577.494589  1295.146799     1.424606     1.10899     0.809188
# min       1.000000   501.000000     1.000000     1.00000     1.000000
# 25%     500.750000  1653.000000     2.000000     2.00000     1.000000
# 50%    1000.500000  2833.000000     3.000000     3.00000     2.000000
# 75%    1500.250000  3887.500000     4.000000     4.00000     3.000000
# max    2000.000000  4999.000000     5.000000     4.00000     3.000000
#
#          YearBuilt          Price
# count  2000.000000    2000.000000
# mean   1961.446000  537676.855000
# std      35.926695  276428.845719
# min    1900.000000   50005.000000
# 25%    1930.000000  300098.000000
# 50%    1961.000000  539254.000000
# 75%    1993.000000  780086.000000
# max    2023.000000  999656.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Id         2000 non-null   int64
#  1   Area       2000 non-null   int64
#  2   Bedrooms   2000 non-null   int64
#  3   Bathrooms  2000 non-null   int64
#  4   Floors     2000 non-null   int64
#  5   YearBuilt  2000 non-null   int64
#  6   Location   2000 non-null   str
#  7   Condition  2000 non-null   str
#  8   Garage     2000 non-null   str
#  9   Price      2000 non-null   int64
# dtypes: int64(7), str(3)
# memory usage: 156.4 KB

# %% [markdown]
# # 5.1 Importing the JSON File and getting the basic info

# %%
url = "https://jsonplaceholder.typicode.com/users"

df5 = pd.read_json(url)

df5.head()
# Out:
#    id              name   username                      email  \
# 0   1     Leanne Graham       Bret          Sincere@april.biz
# 1   2      Ervin Howell  Antonette          Shanna@melissa.tv
# 2   3  Clementine Bauch   Samantha         Nathan@yesenia.net
# 3   4  Patricia Lebsack   Karianne  Julianne.OConner@kory.org
# 4   5  Chelsey Dietrich     Kamren   Lucio_Hettinger@annie.ca
#
#                                              address                  phone  \
# 0  {'street': 'Kulas Light', 'suite': 'Apt. 556',...  1-770-736-8031 x56442
# 1  {'street': 'Victor Plains', 'suite': 'Suite 87...    010-692-6593 x09125
# 2  {'street': 'Douglas Extension', 'suite': 'Suit...         1-463-123-4447
# 3  {'street': 'Hoeger Mall', 'suite': 'Apt. 692',...      493-170-9623 x156
# 4  {'street': 'Skiles Walks', 'suite': 'Suite 351...          (254)954-1289
#
#          website                                            company
# ...

# %%
df5.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        10 non-null     int64
#  1   name      10 non-null     str
#  2   username  10 non-null     str
#  3   email     10 non-null     str
#  4   address   10 non-null     object
#  5   phone     10 non-null     str
#  6   website   10 non-null     str
#  7   company   10 non-null     object
# dtypes: int64(1), object(2), str(5)
# memory usage: 772.0+ bytes
